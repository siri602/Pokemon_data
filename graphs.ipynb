# %%
# %pip install matplotlib
# Out:
# ...
#      ---------------------------------------- 0.0/80.3 kB ? eta -:--:--
#      ----- ---------------------------------- 10.2/80.3 kB ? eta -:--:--
#      ----- ---------------------------------- 10.2/80.3 kB ? eta -:--:--
#      ------------------- ------------------ 41.0/80.3 kB 245.8 kB/s eta 0:00:01
#      -------------------------------------- 80.3/80.3 kB 448.9 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/121.0 kB ? eta -:--:--
#      -------------------------------------- 121.0/121.0 kB 6.9 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/9.3 MB ? eta -:--:--
#     --------------------------------------- 0.2/9.3 MB 3.7 MB/s eta 0:00:03
#    - -------------------------------------- 0.3/9.3 MB 3.2 MB/s eta 0:00:03
#    - -------------------------------------- 0.4/9.3 MB 3.0 MB/s eta 0:00:03
#    -- ------------------------------------- 0.6/9.3 MB 3.0 MB/s eta 0:00:03
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("Ice Cream Ratings.csv").set_index('Date')
df
# Out:
#           Flavor Rating  Texture Rating  Overall Rating
# Date
# 1/1/2022       0.223090        0.040220        0.600129
# 1/2/2022       0.635886        0.938476        0.106264
# 1/3/2022       0.442323        0.044154        0.598112
# 1/4/2022       0.389128        0.549676        0.489353
# 1/5/2022       0.386887        0.519439        0.988280
# 1/6/2022       0.877984        0.193588        0.832827
# 1/7/2022       0.140995        0.325110        0.105147

# %%
df.plot(kind='bar',stacked=True)
# Out:
# <Axes: xlabel='Date'>

# %%
df.plot(kind='line',title='Ice Cream Analysis',xlabel='time',ylabel='Scores')
# Out:
# <Axes: title={'center': 'Ice Cream Analysis'}, xlabel='time', ylabel='Scores'>

# %%
df.plot(subplots=True)
# Out:
# array([<Axes: xlabel='Date'>, <Axes: xlabel='Date'>,
#        <Axes: xlabel='Date'>], dtype=object)

# %%
df.plot.barh(stacked=True)
# Out:
# <Axes: ylabel='Date'>

# %%
df['Overall Rating'].plot(kind='bar')
# Out:
# <Axes: xlabel='Date'>

# %%
df.plot(kind='scatter',x='Overall Rating',y='Flavor Rating',s=50,c='red')
# Out:
# <Axes: xlabel='Overall Rating', ylabel='Flavor Rating'>
